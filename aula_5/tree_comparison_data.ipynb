# %%
"""
Number of items: 4
Average search times:
> Red Black Tree: 1370.3869ns.
> Binary Tree: 1639.7302ns.

Number of items: 16
Average search times:
> Red Black Tree: 1321.5909ns.
> Binary Tree: 1324.8243ns.

Number of items: 64
Average search times:
> Red Black Tree: 1313.0117ns.
> Binary Tree: 1337.8853ns.

Number of items: 256
Average search times:
> Red Black Tree: 1235.005ns.
> Binary Tree: 1275.8613ns.

Number of items: 1024
Average search times:
> Red Black Tree: 1263.1413ns.
> Binary Tree: 1327.2945ns.

Number of items: 4096
Average search times:
> Red Black Tree: 1491.4444ns.
> Binary Tree: 1548.2191ns.

Number of items: 16384
Average search times:
> Red Black Tree: 1766.026ns.
> Binary Tree: 1770.1312ns.

Number of items: 65536
Average search times:
> Red Black Tree: 2084.946ns.
> Binary Tree: 1902.1522ns.

Number of items: 262144
Average search times:
> Red Black Tree: 2429.7735ns.
> Binary Tree: 2229.157ns.

Number of items: 1048576
Average search times:
> Red Black Tree: 2774.9651ns.
> Binary Tree: 2295.5864ns.

Number of items: 4194304
Average search times:
> Red Black Tree: 3297.7298ns.
> Binary Tree: 2649.442ns.

Number of items: 16777216
Average search times:
> Red Black Tree: 4303.9612ns.
> Binary Tree: 3031.1637ns.


"""

import matplotlib.pyplot as plt
import numpy as np

x_ticks = [
'4¹',
'4²',
'4³',
'4⁴',
'4⁵',
'4⁶',
'4⁷',
'4⁸',
'4⁹',
'4⁰',
'4¹¹',
'4¹²',
]
red_black_times = [
1370.3869,
1321.5909,
1313.0117,
1235.005,
1263.1413,
1491.4444,
1766.026,
2084.946,
2429.7735,
2774.9651,
3297.7298,
4303.9612,
]
binary_times = [
1639.7302,
1324.8243,
1337.8853,
1275.8613,
1327.2945,
1548.2191,
1770.1312,
1902.1522,
2229.157,
2295.5864,
2649.442,
3031.1637,
]

y1 = np.array(red_black_times)
y2 = np.array(binary_times)

plt.plot(y1,'r-',label='Red Black Tree')
plt.plot(y2,'b-',label='AVL Tree')

plt.legend()

plt.title("Comparação tempos busca Red Black Tree x AVL Tree")
plt.xlabel("Numero de nós")
plt.ylabel("Tempo de Busca (ns)")


y_ticks = plt.gca().get_yticks()
y_labels = [f'{int(tick)} ns' for tick in y_ticks]
plt.gca().set_yticklabels(y_labels)

plt.xticks(range(12), x_ticks)

plt.show()
# Out:
# /tmp/ipykernel_105316/3042002209.py:126: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plt.gca().set_yticklabels(y_labels)
